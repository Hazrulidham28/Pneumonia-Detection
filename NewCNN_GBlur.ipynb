# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
# Out:
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Data generators
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)
test_datagen = ImageDataGenerator(rescale=1/255)

# %%
#load dataset
train_dataset = train_datagen.flow_from_directory('ProjectImage/Gaussion blur/train',
                                                  target_size=(180, 180),
                                                  batch_size=32,
                                                  class_mode='categorical')

val_dataset = validation_datagen.flow_from_directory('ProjectImage/Gaussion blur/val',
                                                     target_size=(180, 180),
                                                     batch_size=32,
                                                     class_mode='categorical')

test_dataset = test_datagen.flow_from_directory('ProjectImage/Gaussion blur/val',
                                                target_size=(180, 180),
                                                batch_size=32,
                                                shuffle=False,
                                                class_mode='categorical')
# Out:
# Found 1596 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.

# %%
# Get the class labels and their corresponding indices from the train dataset
classes_train = train_dataset.class_indices

# %%
# Print the classes
print("Classes in the train dataset:")
for class_name, class_index in classes_train.items():
    print(f"Class index: {class_index} - Class name: {class_name}")
# Out:
# Classes in the train dataset:
# Class index: 0 - Class name: NORMAL
# Class index: 1 - Class name: PNEUMONIA

# %%
# One-hot encode train and validation labels
from tensorflow.keras.utils import to_categorical
num_classes = 3  # Assuming you have 3 classes
one_hot_train_labels = to_categorical(train_dataset.labels, num_classes=num_classes)
one_hot_validation_labels = to_categorical(val_dataset.labels, num_classes=num_classes)

# %%
# Get some sample images and their corresponding labels
sample_images, sample_labels = next(train_dataset)

# %%
import matplotlib.pyplot as plt
# Define a function to display images
def display_images(images, labels, num_images=5):
    plt.figure(figsize=(10, 10))
    for i in range(num_images):
        plt.subplot(1, num_images, i+1)
        plt.imshow(images[i])
        plt.axis('off')
    plt.show()

# Display some sample images
display_images(sample_images, sample_labels)

# %%
# Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(180, 180, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Output layer with 7 units for 7 classes
])
# Out:
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 26309186 (100.36 MB)
# Trainable params: 26309186 (100.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
CNN_FOOD_CHOSEN = model.fit(train_dataset,
                              validation_data=val_dataset,
                              epochs=10,
                              batch_size=32)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Hazrul Idham\Documents\ANACONDA\envs\tfNew\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 50/50 [==============================] - 34s 650ms/step - loss: 0.9051 - accuracy: 0.6754 - val_loss: 0.2014 - val_accuracy: 0.9332
# Epoch 2/10
# 50/50 [==============================] - 33s 650ms/step - loss: 0.2117 - accuracy: 0.9254 - val_loss: 0.1208 - val_accuracy: 0.9653
# Epoch 3/10
# 50/50 [==============================] - 33s 657ms/step - loss: 0.1350 - accuracy: 0.9568 - val_loss: 0.1354 - val_accuracy: 0.9480
# Epoch 4/10
# 50/50 [==============================] - 33s 657ms/step - loss: 0.0914 - accuracy: 0.9693 - val_loss: 0.1360 - val_accuracy: 0.9480
# Epoch 5/10
# 50/50 [==============================] - 33s 661ms/step - loss: 0.0804 - accuracy: 0.9749 - val_loss: 0.0654 - val_accuracy: 0.9802
# Epoch 6/10
# 50/50 [==============================] - 33s 659ms/step - loss: 0.0871 - accuracy: 0.9680 - val_loss: 0.0951 - val_accuracy: 0.9579
# Epoch 7/10
# 50/50 [==============================] - 33s 660ms/step - loss: 0.0575 - accuracy: 0.9799 - val_loss: 0.1280 - val_accuracy: 0.9554
# Epoch 8/10
# 50/50 [==============================] - 33s 661ms/step - loss: 0.0606 - accuracy: 0.9793 - val_loss: 0.0926 - val_accuracy: 0.9653
# Epoch 9/10
# 50/50 [==============================] - 33s 667ms/step - loss: 0.0461 - accuracy: 0.9837 - val_loss: 0.1470 - val_accuracy: 0.9554
# Epoch 10/10
# 50/50 [==============================] - 34s 668ms/step - loss: 0.0398 - accuracy: 0.9856 - val_loss: 0.1487 - val_accuracy: 0.9480

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_dataset)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 13/13 [==============================] - 4s 285ms/step - loss: 0.1487 - accuracy: 0.9480
# Test Loss: 0.14871980249881744
# Test Accuracy: 0.948019802570343

# %%
# Predict the labels for the test dataset
test_predictions = model.predict(test_dataset)
predicted_classes = np.argmax(test_predictions, axis=1)
# Out:
# 13/13 [==============================] - 4s 291ms/step

# %%
# Ensure true classes are correctly aligned
true_classes =test_dataset.classes

# %%
# Verify the lengths of predictions and true labels match
assert len(predicted_classes) == len(true_classes), "Mismatch between predicted and true label counts"

# %%
# Compute the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[181  21]
#  [  0 202]]

# %%
# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(test_dataset.class_indices.keys()))
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=45)
plt.show()

# %%
# Compute the classification report including the F1-score
report = classification_report(true_classes, predicted_classes, target_names=list(test_dataset.class_indices.keys()))
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       NORMAL       1.00      0.90      0.95       202
#    PNEUMONIA       0.91      1.00      0.95       202
#
#     accuracy                           0.95       404
#    macro avg       0.95      0.95      0.95       404
# weighted avg       0.95      0.95      0.95       404
